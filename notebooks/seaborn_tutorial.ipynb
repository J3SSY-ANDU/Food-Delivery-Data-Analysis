# %%
import pandas as pd

df = pd.read_csv('../data/test/housing.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
import seaborn as sns

g = sns.relplot(kind='scatter', data=df, x='longitude', y='latitude') # Relational plot (continuous data), kind='scatter' for scatter plot
g.set(title='Geographical Location of Areas in California')

# %%
g = sns.relplot(kind='scatter', data=df, x='longitude', y='latitude', hue='median_house_value') # Relational plot with hue for median house value
g.set(title='Geographical Location of Areas in California')

# %%
g = sns.relplot(kind='scatter', data=df, x='longitude', y='latitude', hue='ocean_proximity') # Relational plot with hue for ocean proximity
g.set(title='Geographical Location of Areas in California')

# %%
df['above_median_house_value'] = (df.median_house_value > df.median_house_value.median()).astype(int) # Create a new column indicating if the median house value is above the median value
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
g = sns.relplot(kind='scatter', data=df, x='longitude', y='latitude', hue='above_median_house_value') # Relational plot with hue for above median house value
g.set(title='Geographical Location of Areas in California')

# %%
g = sns.relplot(kind='scatter', data=df, x='longitude', y='latitude', style='above_median_house_value')
g.set(title='Geographical Location of Areas in California')

# %%
g = sns.relplot(kind='scatter', data=df, x='longitude', y='latitude', style='above_median_house_value', hue='above_median_house_value')
g.set(title='Geographical Location of Areas in California')

# %%
g = sns.relplot(kind='scatter', data=df, x='longitude', y='latitude', style='above_median_house_value', hue='above_median_house_value', size='median_house_value')
g.set(title='Geographical Location of Areas in California')

# %%
weather_df = pd.read_csv('../data/test/jena_climate_2009_2016.csv')
weather_df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# ...

# %%
from copy import deepcopy

weather_df = weather_df[::6*24][:365] # Take one sample every 6 hours for one year
weather_df.reset_index(drop=True, inplace=True)

weather_df_full = deepcopy(weather_df)

weather_df = weather_df[['Date Time', 'p (mbar)', 'T (degC)']]

weather_df
# Out:
#                Date Time  p (mbar)  T (degC)
# 0    01.01.2009 00:10:00    996.52     -8.02
# 1    02.01.2009 00:10:00    999.55     -4.60
# 2    03.01.2009 00:10:00   1002.39     -4.89
# 3    04.01.2009 00:10:00    992.79     -1.83
# 4    05.01.2009 00:10:00    985.06     -1.50
# ..                   ...       ...       ...
# 360  27.12.2009 00:30:00    981.38     -0.70
# 361  28.12.2009 00:30:00    975.40      1.66
# 362  29.12.2009 00:30:00    981.81     -2.18
# 363  30.12.2009 00:30:00    969.94     -0.70
# 364  31.12.2009 00:30:00    967.84     -0.68
#
# [365 rows x 3 columns]

# %%
weather_df['Date Time']
# Out:
# 0      01.01.2009 00:10:00
# 1      02.01.2009 00:10:00
# 2      03.01.2009 00:10:00
# 3      04.01.2009 00:10:00
# 4      05.01.2009 00:10:00
#               ...
# 360    27.12.2009 00:30:00
# 361    28.12.2009 00:30:00
# 362    29.12.2009 00:30:00
# 363    30.12.2009 00:30:00
# 364    31.12.2009 00:30:00
# Name: Date Time, Length: 365, dtype: object

# %%
weather_df = deepcopy(weather_df)
weather_df['Date Time'] = pd.to_datetime(weather_df['Date Time'], format='%d.%m.%Y %H:%M:%S')

weather_df['Date Time']
# Out:
# 0     2009-01-01 00:10:00
# 1     2009-01-02 00:10:00
# 2     2009-01-03 00:10:00
# 3     2009-01-04 00:10:00
# 4     2009-01-05 00:10:00
#               ...
# 360   2009-12-27 00:30:00
# 361   2009-12-28 00:30:00
# 362   2009-12-29 00:30:00
# 363   2009-12-30 00:30:00
# 364   2009-12-31 00:30:00
# Name: Date Time, Length: 365, dtype: datetime64[ns]

# %%
weather_df.head()
# Out:
#             Date Time  p (mbar)  T (degC)
# 0 2009-01-01 00:10:00    996.52     -8.02
# 1 2009-01-02 00:10:00    999.55     -4.60
# 2 2009-01-03 00:10:00   1002.39     -4.89
# 3 2009-01-04 00:10:00    992.79     -1.83
# 4 2009-01-05 00:10:00    985.06     -1.50

# %%
sns.lineplot(x='Date Time', y='T (degC)', data=weather_df)
# Out:
# <Axes: xlabel='Date Time', ylabel='T (degC)'>

# %%
g = sns.lineplot(x='Date Time', y='T (degC)', data=weather_df)
g.figure.autofmt_xdate() # Rotate x-axis labels for better readability

# %%
weather_df_shuffled = weather_df.sample(frac=1) # Shuffle the DataFrame
weather_df_shuffled.reset_index(drop=True, inplace=True) # Reset index after shuffling

weather_df_shuffled
# Out:
#               Date Time  p (mbar)  T (degC)
# 0   2009-09-25 00:10:00    997.81     10.07
# 1   2009-05-16 00:10:00    981.71     11.79
# 2   2009-09-15 00:10:00    990.46     12.95
# 3   2009-04-06 00:10:00    994.91      7.26
# 4   2009-05-06 00:10:00    989.83      8.43
# ..                  ...       ...       ...
# 360 2009-02-10 00:10:00    973.37     -0.10
# 361 2009-05-11 00:10:00    992.89     10.76
# 362 2009-11-09 00:30:00    981.31      3.77
# 363 2009-02-13 00:10:00    989.31     -2.11
# 364 2009-04-03 00:10:00    991.86      9.34
#
# [365 rows x 3 columns]

# %%
g = sns.lineplot(x='Date Time', y='T (degC)', data=weather_df_shuffled) # Plot shuffled data
g.figure.autofmt_xdate()

# %%
weather_df['above_average_pressure'] = (weather_df['p (mbar)'] > weather_df['p (mbar)'].mean()).astype(int)
weather_df
# Out:
#               Date Time  p (mbar)  T (degC)  above_average_pressure
# 0   2009-01-01 00:10:00    996.52     -8.02                       1
# 1   2009-01-02 00:10:00    999.55     -4.60                       1
# 2   2009-01-03 00:10:00   1002.39     -4.89                       1
# 3   2009-01-04 00:10:00    992.79     -1.83                       1
# 4   2009-01-05 00:10:00    985.06     -1.50                       0
# ..                  ...       ...       ...                     ...
# 360 2009-12-27 00:30:00    981.38     -0.70                       0
# 361 2009-12-28 00:30:00    975.40      1.66                       0
# 362 2009-12-29 00:30:00    981.81     -2.18                       0
# 363 2009-12-30 00:30:00    969.94     -0.70                       0
# 364 2009-12-31 00:30:00    967.84     -0.68                       0
#
# [365 rows x 4 columns]

# %%
g = sns.lineplot(x='Date Time', y='T (degC)', markers=True, style='above_average_pressure', hue='above_average_pressure', data=weather_df) # Plot with hue based on pressure
g.figure.autofmt_xdate()

# %%
weather_df['above_average_pressure'].value_counts() # Count of above and below average pressure
# Out:
# above_average_pressure
# 1    204
# 0    161
# Name: count, dtype: int64

# %%
g = sns.relplot(x='Date Time', y='T (degC)', markers=True, style='above_average_pressure', hue='above_average_pressure', kind='line', col='above_average_pressure', data=weather_df) # Plot with hue based on pressure
g.figure.autofmt_xdate()

# %%
sns.catplot(x='total_rooms', y='ocean_proximity', data=df)

# %%
sns.catplot(x='median_house_value', y='ocean_proximity', data=df, hue='above_median_house_value')

# %%
sns.boxplot(x='median_house_value', y='ocean_proximity', data=df, hue='above_median_house_value')
# Out:
# <Axes: xlabel='median_house_value', ylabel='ocean_proximity'>

# %%
sns.boxplot(x='housing_median_age', y='ocean_proximity', data=df, hue='above_median_house_value')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='ocean_proximity'>

# %%
sns.violinplot(y='median_house_value', x='ocean_proximity', data=df)
# Out:
# <Axes: xlabel='ocean_proximity', ylabel='median_house_value'>

# %%
titanic = sns.load_dataset('titanic') # Load the Titanic dataset
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.histplot(data=titanic, x='age', bins=30, kde=True, stat='percent', hue='sex') # Histogram with KDE for age distribution
# kde=True adds a kernel density estimate line to the histogram
# Out:
# <Axes: xlabel='age', ylabel='Percent'>

# %%
titanic['sex'].value_counts() # Male vs Female count in Titanic dataset
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.barplot(x='sex', y='age', data=titanic) # Bar plot by default shows the average of the data for each category
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(x='sex', y='age', estimator=sum, data=titanic) # Bar plot with sum as the estimator
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.barplot(y='survived', x='sex', data=titanic) # Bar plot showing survival rate by sex
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.catplot(kind='bar', x='sex', y='survived', hue='class', data=titanic) # Catplot for bar plot of survival rate

# %%
sns.catplot(kind='bar', x='sex', y='survived', hue='class', col='class', data=titanic) # Catplot with columns for each class

# %%
import numpy as np
g = sns.histplot(data=titanic, x='class', hue='survived') # Stacked histogram for class and survival
g.set_yticks(np.arange(0, 381, 10))
g.figure.set_size_inches(8, 10)  # width=8, height=6 (in inches)
g.set(title='Survival by Class on Titanic')
# Out:
# [Text(0.5, 1.0, 'Survival by Class on Titanic')]

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
town_counts = titanic['embark_town'].value_counts()
print(town_counts) # Count of passengers by embarkation town
g = sns.catplot(kind='bar', x='embark_town', y='survived', hue='class', estimator=sum, data=titanic) # Bar plot for embarkation town and survival
g.set(title='Survival by Embarkation Town on Titanic')
# Out:
# embark_town
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
g = sns.histplot(x='embark_town', hue='class', data=titanic, stat='percent', multiple='stack') # Stacked histogram for embarkation town and class
g.set_yticks(np.arange(0,76,5))
g.figure.set_size_inches(8, 10)  # width=8, height=6 (in inches)
g.set(title='Passenger Distribution by Embarkation Town and Class on Titanic')
# Out:
# [Text(0.5, 1.0, 'Passenger Distribution by Embarkation Town and Class on Titanic')]

# %%
g = sns.boxplot(x='class', y='fare', hue='sex', data=titanic)
g.set(title='Fare Distribution by Class on Titanic')
g.figure.set_size_inches(6, 12)  # width=8, height=6 (in inches)
g.set_yticks(np.arange(0, 551, 25))
titanic['fare'].describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: fare, dtype: float64

# %%
outliers_over_500 = titanic[(titanic['fare'] > 500)]['survived'].value_counts()
print(outliers_over_500)  # Display outliers in fare greater than 500

outliers_under_5 = titanic[(titanic['fare'] < 5)]['survived'].value_counts()
print(outliers_under_5)  # Display outliers in fare less than 5
# Out:
# survived
# 1    3
# Name: count, dtype: int64
# survived
# 0    15
# 1     1
# Name: count, dtype: int64

# %%
titanic['deck'].value_counts()  # Count of passengers by deck
g = sns.catplot(kind='bar', x='deck', y='survived', hue='class', data=titanic)  # Bar plot for deck and survival
g.set(title='Survival by Deck on Titanic')

# %%
g = sns.catplot(kind='bar', x='sex', y='survived', hue='alone', data=titanic)  # Bar plot for embarkation town and survival
g.set(title='Survival by Alone Status on Titanic')
